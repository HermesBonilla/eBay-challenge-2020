# %%
# !pip list
# Out:
# WARNING: The directory '/home/jovyan/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Package                Version
# ---------------------- --------------
# async-generator        1.10
# attrs                  20.3.0
# backcall               0.2.0
# bleach                 3.2.1
# certifi                2020.11.8
# chardet                3.0.4
# cycler                 0.10.0
# decorator              4.4.2
# defusedxml             0.6.0
# dill                   0.3.3
# entrypoints            0.3
# idna                   2.10
# imageio                2.9.0
# importlib-metadata     3.3.0
# ipykernel              5.4.2
# ipython                7.19.0
# ipython-genutils       0.2.0
# ipywidgets             7.5.1
# jedi                   0.17.2
# Jinja2                 2.11.2
# joblib                 0.17.0
# jsonschema             3.2.0
# jupyter-client         6.1.7
# jupyter-core           4.7.0
# jupyterlab-pygments    0.1.2
# kiwisolver             1.3.1
# MarkupSafe             1.1.1
# matplotlib             3.3.3
# mistune                0.8.4
# nbclient               0.5.1
# nbconvert              6.0.7
# nbformat               5.0.8
# nest-asyncio           1.4.3
# networkx               2.5
# notebook               7.0.0.dev0
# numpy                  1.19.4
# packaging              20.8
# pandas                 1.0.5
# pandocfilters          1.4.3
# parso                  0.7.1
# pexpect                4.8.0
# pickleshare            0.7.5
# Pillow                 8.0.1
# pip                    20.2.4
# pluggy                 0.13.1
# prometheus-client      0.9.0
# prompt-toolkit         3.0.8
# psycopg2-binary        2.8.6
# ptyprocess             0.6.0
# Pygments               2.7.3
# pyparsing              2.4.7
# pyrsistent             0.17.3
# python-dateutil        2.8.1
# python-jsonrpc-server  0.4.0
# python-language-server 0.5+1.g6266675
# pytz                   2020.4
# PyWavelets             1.1.1
# pyzmq                  20.0.0
# requests               2.25.0
# scikit-image           0.18.1
# scikit-learn           0.23.2
# scipy                  1.5.4
# Send2Trash             1.5.0
# setuptools             50.3.2
# six                    1.15.0
# terminado              0.9.1
# testpath               0.4.4
# threadpoolctl          2.1.0
# tifffile               2020.12.8
# tornado                6.1
# traitlets              5.0.5
# typing-extensions      3.7.4.3
# ujson                  4.0.1
# urllib3                1.26.2
# wcwidth                0.2.5
# webencodings           0.5.1
# wheel                  0.35.1
# widgetsnbextension     3.5.1
# zipp                   3.4.0
# WARNING: You are using pip version 20.2.4; however, version 20.3.3 is available.
# You should consider upgrading via the '/opt/venv/bin/python -m pip install --upgrade pip' command.

# %%
# !python -m pip install -U scikit-image
# Out:
# WARNING: The directory '/home/jovyan/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Requirement already up-to-date: scikit-image in /opt/venv/lib/python3.7/site-packages (0.18.1)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /opt/venv/lib/python3.7/site-packages (from scikit-image) (2.5)
# Requirement already satisfied, skipping upgrade: scipy>=1.0.1 in /opt/venv/lib/python3.7/site-packages (from scikit-image) (1.5.4)
# Requirement already satisfied, skipping upgrade: numpy>=1.16.5 in /opt/venv/lib/python3.7/site-packages (from scikit-image) (1.19.4)
# Requirement already satisfied, skipping upgrade: imageio>=2.3.0 in /opt/venv/lib/python3.7/site-packages (from scikit-image) (2.9.0)
# Requirement already satisfied, skipping upgrade: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /opt/venv/lib/python3.7/site-packages (from scikit-image) (8.0.1)
# Requirement already satisfied, skipping upgrade: tifffile>=2019.7.26 in /opt/venv/lib/python3.7/site-packages (from scikit-image) (2020.12.8)
# Requirement already satisfied, skipping upgrade: PyWavelets>=1.1.1 in /opt/venv/lib/python3.7/site-packages (from scikit-image) (1.1.1)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.0.0,>=2.0.0 in /opt/venv/lib/python3.7/site-packages (from scikit-image) (3.3.3)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from networkx>=2.0->scikit-image) (4.4.2)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /opt/venv/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (1.3.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (2.4.7)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (2.8.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /opt/venv/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (0.10.0)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from python-dateutil>=2.1->matplotlib!=3.0.0,>=2.0.0->scikit-image) (1.15.0)
# WARNING: You are using pip version 20.2.4; however, version 20.3.3 is available.
# You should consider upgrading via the '/opt/venv/bin/python -m pip install --upgrade pip' command.

# %%
#Setup

#Import statements
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from skimage.io import imread

#Plt
plt.style.use('seaborn-whitegrid')

# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# %%
#File paths and names of data
# !ls /datasets/ebay-data
# Out:
# mlchallenge_set_2021.tsv  mlchallenge_set_validation.tsv

# %%
cNames =  ["Category", "Primary Image", "Other Images", "Attributes", "Index"]
dataset = pd.read_csv('/datasets/ebay-data/mlchallenge_set_2021.tsv',sep = '\t', header=None, names = cNames)

# %%
dataset.head(5)
# Out:
#    Category                                      Primary Image  \
# 0         2  https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/iYYA...
# 1         2  https://i.ebayimg.com/00/s/MTA1OFgxMTM0/z/KPIA...
# 2         2  https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/flIA...
# 3         2  http://i.ebayimg.com/00/s/ODAwWDEwNjc=/z/XHcAA...
# 4         2  https://i.ebayimg.com/00/s/MTA2N1gxNjAw/z/scsA...
#
#                                         Other Images  \
# 0  https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/iYYA...
# 1  https://i.ebayimg.com/00/s/MTA1OFgxMTM0/z/KPIA...
# 2  https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/flIA...
# 3  http://i.ebayimg.com/00/s/ODAwWDEwNjc=/z/XHcAA...
# 4  https://i.ebayimg.com/00/s/MTA2N1gxNjAw/z/scsA...
#
#                                           Attributes  Index
# 0  (Brand:Shimano,US Shoe Size (Men's):4.5,Modifi...      0
# 1  (Color:Gray/White,Country/Region of Manufactur...      1
# 2  (Style:Cleats,Color:White Orange,US Shoe Size ...      2
# 3  (Width:Medium (D, M),US Size:9,Brand:VANS,Colo...      3
# 4  (US Shoe Size (Men's):10.5,Material:Enter item...      4

# %%
dataset.set_index('Index', inplace=True)
dataset.head(5)
# Out:
#        Category                                      Primary Image  \
# Index
# 0             2  https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/iYYA...
# 1             2  https://i.ebayimg.com/00/s/MTA1OFgxMTM0/z/KPIA...
# 2             2  https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/flIA...
# 3             2  http://i.ebayimg.com/00/s/ODAwWDEwNjc=/z/XHcAA...
# 4             2  https://i.ebayimg.com/00/s/MTA2N1gxNjAw/z/scsA...
#
#                                             Other Images  \
# Index
# 0      https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/iYYA...
# 1      https://i.ebayimg.com/00/s/MTA1OFgxMTM0/z/KPIA...
# 2      https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/flIA...
# 3      http://i.ebayimg.com/00/s/ODAwWDEwNjc=/z/XHcAA...
# 4      https://i.ebayimg.com/00/s/MTA2N1gxNjAw/z/scsA...
#
#                                               Attributes
# Index
# 0      (Brand:Shimano,US Shoe Size (Men's):4.5,Modifi...
# 1      (Color:Gray/White,Country/Region of Manufactur...
# 2      (Style:Cleats,Color:White Orange,US Shoe Size ...
# 3      (Width:Medium (D, M),US Size:9,Brand:VANS,Colo...
# 4      (US Shoe Size (Men's):10.5,Material:Enter item...

# %%
cols = dataset.columns.tolist()
cols
# Out:
# ['Category', 'Primary Image', 'Other Images', 'Attributes']

# %%
cols = cols[1:] + [cols[0]]
cols
# Out:
# ['Primary Image', 'Other Images', 'Attributes', 'Category']

# %%
dataset = dataset[cols]
dataset.head(5)
# Out:
#                                            Primary Image  \
# Index
# 0      https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/iYYA...
# 1      https://i.ebayimg.com/00/s/MTA1OFgxMTM0/z/KPIA...
# 2      https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/flIA...
# 3      http://i.ebayimg.com/00/s/ODAwWDEwNjc=/z/XHcAA...
# 4      https://i.ebayimg.com/00/s/MTA2N1gxNjAw/z/scsA...
#
#                                             Other Images  \
# Index
# 0      https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/iYYA...
# 1      https://i.ebayimg.com/00/s/MTA1OFgxMTM0/z/KPIA...
# 2      https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/flIA...
# 3      http://i.ebayimg.com/00/s/ODAwWDEwNjc=/z/XHcAA...
# 4      https://i.ebayimg.com/00/s/MTA2N1gxNjAw/z/scsA...
#
#                                               Attributes  Category
# Index
# 0      (Brand:Shimano,US Shoe Size (Men's):4.5,Modifi...         2
# 1      (Color:Gray/White,Country/Region of Manufactur...         2
# 2      (Style:Cleats,Color:White Orange,US Shoe Size ...         2
# 3      (Width:Medium (D, M),US Size:9,Brand:VANS,Colo...         2
# 4      (US Shoe Size (Men's):10.5,Material:Enter item...         2

# %%
#Function to parse attributes, to be tested

import re

def parse_attributes(attrib):
    #Remove parentheses
    attrib = re.sub('[()]', '', attrib)
    
    #Split by colon(s))
    attrib = re.split(':+', attrib)
    
    #Inner comma split
    lta = len(attrib) #Variable to hold length of attributes
    # ["Colors", "blue,white,Special Note", "very nice,Style", "Modern"]
    
    for i in range(lta):
        attrib[i] = attrib[i].split(',')
    
    #Lists to hold terms
    nonLastTerms = []
    lastTerms = []
    
    #Split into terms
    for i in range(lta):
        if len(attrib[i]) == 1 and i < lta - 1:
            lastTerms.append(attrib[i][0])
        elif len(attrib[i]) == 1 and i == lta - 1:
            nonLastTerms.append(attrib[i][-1])
        elif len(attrib[i]) > 1:
            lastTerms.append(attrib[i][-1])
            nonLastTerms.append(attrib[i][:-1])
        
    #Make combine the list values and make the dictionary
    for i in range(len(nonLastTerms)):
        nonLastTerms[i] = (",".join(nonLastTerms[i]) if type(nonLastTerms[i]) is list else nonLastTerms[i])
        
    attrib = dict(zip(lastTerms, nonLastTerms))
    
    return attrib

# %%
#Testing attribute parsing

mod_dataset = pd.DataFrame()
mod_dataset['Attributes'] = dataset['Attributes'].apply(lambda x: parse_attributes(x))
mod_dataset.head(20)
# mod_dataset.iloc[0]
# Out:
#                                               Attributes
# Index
# 0      {'Brand': 'Shimano', 'US Shoe Size Men's': '4....
# 1      {'Color': 'Gray/White', 'Country/Region of Man...
# 2      {'Style': 'Cleats', 'Color': 'White Orange', '...
# 3      {'Width': 'Medium D, M', 'US Size': '9', 'Bran...
# 4      {'US Shoe Size Men's': '10.5', 'Material': 'En...
# 5      {'US Shoe Size Men's': '7', 'Brand': 'AMA BRAN...
# 6      {'Style': 'Athletic Sneakers', 'US Shoe Size M...
# 7      {'Style': 'Skateboarding', 'Brand': 'Nike', 'U...
# 8      {'Brand': 'Brooks', 'Material': 'Mesh / Leathe...
# 9      {'US Shoe Size Men's': '11', 'Brand': 'Ralph L...
# 10     {'US Shoe Size Men's': '9', 'Style': 'Cleats',...
# 11     {'US Shoe Size Men's': '5.5', 'Brand': 'adidas...
# 12     {'Width': 'Medium D', 'Brand': 'ASICS', 'Color...
# 13     {'Country/Region of Manufacture': 'China', 'Br...
# 14     {'Style': 'Skateboarding', 'US Shoe Size Men's...
# 15     {'Brand': 'Nike', 'Color': 'Black', 'Pattern':...
# 16     {'Style': 'Basketball Shoes', 'US Shoe Size Me...
# 17     {'US Shoe Size Men's': '5', 'Style': 'Running,...
# 18     {'Style': 'Basketball Shoes', 'US Shoe Size Me...
# 19     {'Brand': 'Dr. Martens', 'Color': 'Black', 'Ma...

# %%
# untruncated dataframe

pd.set_option('display.max_colwidth', -1)
mod_dataset.head()
# Out:
# /shared-libs/python3.7/py-core/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                                                                                                                                                                                          Attributes
# Index
# 0      {'Brand': 'Shimano', 'US Shoe Size Men's': '4.5', 'Modified Item': 'No', 'Style': 'Cycling'}
# 1      {'Color': 'Gray/White', 'Country/Region of Manufacture': 'Indonesia', 'US Shoe Size Men's': '8', 'Style': 'Athletic Sneakers', 'Brand': 'Giorgio Armani', 'Material': 'Leather Suede'}
# 2      {'Style': 'Cleats', 'Color': 'White Orange', 'US Shoe Size Men's': '15', 'Brand': 'Nike'}
# 3      {'Width': 'Medium D, M', 'US Size': '9', 'Brand': 'VANS', 'Color': 'Green', 'Material': 'Suede & Denim', 'Style': 'Skateboarding', 'Type': 'Athletic', 'Type 2': 'Skateboarding', 'US Shoe Size Men's': '9'}
# 4      {'US Shoe Size Men's': '10.5', 'Material': 'Enter item specific valuePLEASE READ BEFORE BIDDIN', 'Brand': 'Nike', 'Style': 'Basketball Shoes', 'Color': 'Multi-Color'}

# %%
# import re
# #Experimenting

# sample_attributes = '(Colors:blue, white,Special Note::very nice,Style: Modern)'
# sample_attributes = re.sub('[()]', '', sample_attributes)
# print("parenthesis:",sample_attributes)

# sample_attributes = re.split(':+', sample_attributes)
# print("colon split:",sample_attributes)

# lsa = len(sample_attributes)
# for i in range(len(sample_attributes)):
#     sample_attributes[i] = sample_attributes[i].split(',') 
# print("Inner comma split:", sample_attributes)

# #Lists to hold terms
# nonLastTerms = []
# lastTerms = []
    
# #Split into terms

# for i in range(lsa):
#     if len(sample_attributes[i]) == 1 and i < lsa - 1:
#         lastTerms.append(sample_attributes[i][0])
#     elif len(sample_attributes[i]) == 1 and i == lsa - 1:
#         nonLastTerms.append(sample_attributes[i][-1])
#     elif len(sample_attributes[i]) > 1:
#         lastTerms.append(sample_attributes[i][-1])
#         nonLastTerms.append(sample_attributes[i][:-1])


# print("lastTerms:", lastTerms)
# print("nonLastTerms:", nonLastTerms)
# for i in range(len(nonLastTerms)):
#     nonLastTerms[i] = (",".join(nonLastTerms[i]) if type(nonLastTerms[i]) is list else nonLastTerms[i])

# print("nonLastTerms:", nonLastTerms)

# sample_attributes = dict(zip(lastTerms, nonLastTerms))

# print("Combining terms:", sample_attributes)

# %%
#Function to turn images to arrays

# def im2Array(url):
#     pass

# %%
#Experimentation

sample_url = 'https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/iYYAAOxydgZTJwYc/$_1.JPG?set_id=880000500F'

# imArray = imread(sample_url)
# print(imArray.shape) #400 x 300 image in RGB (3) == (400, 300, 3), This is 3D
# imArray2 = np.reshape(imArray, (1,-1))
# print(imArray2.shape) #1 x 360000 reshaped image, This is 2D
# imgplot = plt.imshow(imArray)

# %% [markdown]
# Image to array

# %%
# imports to turn image to array
from PIL import Image
import requests
from io import BytesIO
from skimage.transform import resize

# imports for imagenet models
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.applications.imagenet_utils import decode_predictions

from tensorflow.keras.applications import (
        vgg16,
        resnet50,
        mobilenet,
        inception_v3,
        nasnet,
        xception
)

# %%
# Function to turn images to array - Bryan
# def imgToArray(url):
#     # get image from url
#     response = requests.get(url)
#     original = Image.open(BytesIO(response.content))

#     # convert from PIL to numpy array
#     numpy_image = img_to_array(original)

#     # resize image to (224, 224, 3) -> models expect this input
#     numpy_image = resize(numpy_image, (224, 224))

#     # add another dimensions to the image -> models expects 4th batch dimension
#     image_batch = np.expand_dims(numpy_image, axis=0)

#     return image_batch

# %%
# sample_url = 'https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/iYYAAOxydgZTJwYc/$_1.JPG?set_id=880000500F'

# print(imgToArray(sample_url))

# %% [markdown]
# Image-net models

# %%
# init the models
vgg_model = vgg16.VGG16(weights='imagenet')
inception_model = inception_v3.InceptionV3(weights='imagenet')
resnet_model = resnet50.ResNet50(weights='imagenet')
mobilenet_model = mobilenet.MobileNet(weights='imagenet')
nasnetlarge_model = nasnet.NASNetLarge(weights='imagenet')
xception_model = xception.Xception(weights='imagenet')

# %% [markdown]
# ## Model Dimensions Sheet
#
# **_VGG:_ (None, 224, 224, 3)**
# **_Inception:_ (None, 299, 299, 3)**
# **_Resnet:_ (None, 224, 224, 3)**
# **_Mobilenet:_ (None, 224, 224, 3)**
# **_NASNetLarge:_ (None, 331, 331, 3)**
# **_Xception:_ (None, 299, 299, 3)**

# %%
#Function to predict features of pictures from URL and then return the predicted features in a list of arrays
def predict_image_label(url):
    #get image from url

    response = requests.get(url)
    original = Image.open(BytesIO(response.content))

    # convert from PIL to numpy array
    numpy_image = img_to_array(original)

    # resize image to (224, 224, 3) or (331,331) or (299,299) -> models expect these inputs
    numpy_image_2242243 = resize(numpy_image, (224, 224))
    numpy_image_3313313 = resize(numpy_image, (331, 331))
    numpy_image_2992993 = resize(numpy_image, (299, 299))

    # add another dimensions to the image -> models expects 4th batch dimension
    image_batch_2242243 = np.expand_dims(numpy_image_2242243, axis=0)
    image_batch_3313313 = np.expand_dims(numpy_image_3313313, axis=0)
    image_batch_2992993 = np.expand_dims(numpy_image_2992993, axis=0)
    
    #Hold predictions of each model
    predictions = []

    # vgg expects (None, 224, 224, 3)
    vgg_processed_image = vgg16.preprocess_input(image_batch_2242243.copy())
    vgg_predictions = resnet_model.predict(vgg_processed_image)
    # vgg_predicted_labels = decode_predictions(vgg_predictions)
    predictions.append(vgg_predictions.flatten())

    # inception model expects (None, 299, 299, 3)
    inception_processed_image = inception_v3.preprocess_input(image_batch_2992993.copy())
    inception_predictions = inception_model.predict(inception_processed_image)
    # print("inception type: ", type(inception_predictions))
    # inception_predicted_labels = decode_predictions(inception_predictions)
    predictions.append(inception_predictions.flatten())

    # resnet model expects (None, 224, 224, 3)
    resnet_processed_image = resnet50.preprocess_input(image_batch_2242243.copy())
    resnet_predictions = resnet_model.predict(resnet_processed_image)
    # print("resnet type: ", type(resnet_predictions))
    # resnet_predicted_labels = decode_predictions(resnet_predictions)
    predictions.append(resnet_predictions.flatten())

    # mobilenet model expects (None, 224, 224, 3)
    mobilenet_processed_image = mobilenet.preprocess_input(image_batch_2242243.copy())
    mobilenet_predictions = mobilenet_model.predict(mobilenet_processed_image)
    # print("mobilenet type: ", type(mobilenet_predictions))
    # mobilenet_predicted_labels = decode_predictions(mobilenet_predictions)
    predictions.append(mobilenet_predictions.flatten())

    # NASNetLarge model expects (None, 331, 331, 3)
    nasnetlarge_preprocessed_image = nasnet.preprocess_input(image_batch_3313313.copy())
    nasnetlarge_predictions = nasnetlarge_model.predict(nasnetlarge_preprocessed_image)
    # print("nasnetlarge type: ", type(nasnetlarge_predictions))
    # nasnetlarge_predicted_labels = decode_predictions(nasnetlarge_predictions)
    predictions.append(nasnetlarge_predictions.flatten())

    # Xception model expects (None, 299, 299, 3)
    xception_preprocessed_image = xception.preprocess_input(image_batch_2992993.copy())
    xception_predictions = xception_model.predict(xception_preprocessed_image)
    # print("xception type: ", type(xception_predictions))
    # xception_predicted_labels = decode_predictions(xception_predictions)
    predictions.append(xception_predictions.flatten())

    return predictions

# %%
# 'bedsheet' image
# predict_image_label(imgToArray('https://i.ebayimg.com/00/s/Nzc2WDgzMg==/z/jyQAAOSwBydbno6x/$_57.JPG?set_id=8800005007'))
# predict_image_label('https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/GSQAAOSw9m5b9cT6/$_57.JPG?set_id=8800005007')
# predict_image_label(imgToArray('https://i.ebayimg.com/00/s/NjUwWDY1MA==/z/eR0AAOSwp91ckSjP/$_1.JPG?set_id=880000500F'))

# %%
#Function to add predicted features of original dataset images to mod_dataset
def addPredictedFeatures(pdDataframe):
    """Adds predicted features into a new dataframe
    
    Takes in an original dataframe with image urls, goes through each url, and 
    adds the predicted labels (from predict_image_label()) to the original 
    dataframe.
    """

    #Iterate through the primary image urls and get the flattened features
    #Add the predicted features array to the dataframe when done
    primary_features = []
    for index, row in pdDataframe.iterrows():
        if pd.isnull(row['Primary Image']):
            primary_features.append([np.nan])
        else:
            primary_features.append(predict_image_label(row['Primary Image']))

    pdDataframe['Primary_Features'] = primary_features


    #Iterate over the other image urls and get the flattened features for each
    #Add the array of predicted feature arrays to the dataframe when done
    otherI_features = []
    for index, row in pdDataframe.iterrows():
        if pd.isnull(row['Primary Image']):
            otherI_features.append([np.nan])
        else:
            otherI_features.append([predict_image_label(x) for x in row['Other Images']])

    pdDataframe['OtherI_Features'] = otherI_features

    
    #Explode the column with the other image features
    pdDataframe = pdDataframe.explode('OtherI_Features')
    
    
    return pdDataframe

# %%
# copy of mod_dataframe to add features to dataframe 

f_dataframe = dataset.copy() # f stands for features
f_dataframe['Primary Image'] = f_dataframe['Primary Image'].astype(str)

# addPredictedFeatures(f_dataframe.head())
for index, row in f_dataframe.iterrows():
    print(row['Other Images'])
# Out:
# https://i.ebayimg.com/00/s/MTYwMFgxMjIw/z/E7sAAOSwsV1dMOrI/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxMjIw/z/9GoAAOSwyqddMOrG/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxMjIw/z/MxkAAOSwi6tdMOrF/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/-v0AAOSwr6hdMWmH/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/K~8AAOSwMXZdMWno/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/-TkAAOSwW8ZdMWnm/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/oXoAAOSwLo9dMWmZ/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/N-wAAOSw3LxdMWnB/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/NTMzWDU0OQ==/z/OWIAAOSwPl1dMapj/$_57.PNG?set_id=8800005007;https://i.ebayimg.com/00/s/NTM0WDU5MA==/z/6k0AAOSwP6hdMapg/$_57.PNG?set_id=8800005007;https://i.ebayimg.com/00/s/NTMzWDYwMA==/z/4hgAAOSwgYpdMapc/$_57.PNG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/9N0AAOSwORdc6Hsw/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/FV0AAOSwsztc6Hsz/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/F3gAAOSwC9Fc6Hs2/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/wEsAAOSwQRVc6Hs4/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/vLgAAOSwq4Fc6Hug/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTE5N1g4MDA=/z/j2AAAOSwAUJdMchP/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTE5N1g4MDA=/z/oA4AAOSwcBJdMchP/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/ODAwWDExOTc=/z/LDgAAOSw3nhdMchP/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/ODAwWDExOTc=/z/OX8AAOSwXoZdMchO/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/ODAwWDExOTc=/z/Cp8AAOSwXVpdMchP/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/nx0AAOSwkk5dMcie/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/nzwAAOSwxINdMciL/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/12AAAOSw8j1dMcif/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/8d4AAOSwi~JdMciZ/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/x~4AAOSwxmldMcil/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/Zg4AAOSwpkddMciw/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/oBMAAOSwmd1dMcit/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/ahcAAOSwibddMciV/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/ydQAAOSwKg9dMciR/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/Mc4AAOSwis5dMcij/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/H1IAAOSw2-9dMci1/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTIyNlgxMTg2/z/sSoAAOSwnnpdMdrP/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTQxOVgxMTg2/z/h~cAAOSwUWldMdr9/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTA3MlgxMTg2/z/FpAAAOSwIXZdMdsV/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/lkkAAOSwuzldMdsm/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTQzN1gxMTg2/z/AIQAAOSw2SxdMds9/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTI0OFgxMTg2/z/lIkAAOSw1MhdMdta/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/YgwAAOSw3fNdMeMN/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/w6MAAOSwYMldMeL6/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/eT0AAOSwp-9dMeMA/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/ZXcAAOSwL8BdMeLv/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/qL8AAOSwdx5dMeL9/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/nuAAAOSw7kxdMeLz/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/GJsAAOSwJ81dMeN5/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/c-oAAOSwjgZdMeMG/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/OC8AAOSwSHBdMeMX/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/QKcAAOSwRJZdMeMQ/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/Zm4AAOSw-sRdMeMD/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/zr0AAOSwcvtdMeMK/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/-EQAAOSw8nxbAdaY/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/hJ8AAOSwUwlbAdad/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/vsIAAOSws-tbAdab/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/v9cAAOSwBNtbAdaf/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/l4IAAOSwJo5bAdai/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/gxEAAOSwwB5bt8Qj/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/HkcAAOSwa29bt8Ql/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/OZ8AAOSwpwZbt8Qp/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/-0EAAOSwXW9bt8Qs/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTE1MVgxMTY5/z/zB0AAOSw~E5dMe43/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/Z5sAAOSwztddL7rd/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/rxIAAOSwEMddL7rg/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTE2NFgxMTgy/z/H~QAAOSw6eJdMe5m/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTE5MVgxMTg2/z/ndwAAOSwQ-BdMe6G/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTA1OVgxMTc4/z/5sUAAOSwZbRdMe64/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTM3MVgxMjAw/z/NF4AAOSwxzdZ8pqm/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/4gsAAOSw-eVZ8pqT/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/4-AAAOSwzXxZ8pqW/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/KakAAOSw6GJZ8pqa/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/EW4AAOSwh1hZ8pqc/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/K2AAAOSwldRZ8pqh/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/gdkAAOSwm3pZ8pqr/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/H4EAAOSwEOpZ8pqu/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/xDoAAOSwCcZZ8pqz/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/fA0AAOSwWZpZ8pq9/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/h9AAAOSwWflZ8prD/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTAwMFg3NTA=/z/1BwAAOSwxixZ8qVQ/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTI4MFg5NjA=/z/rs8AAOSwNnRYj58g/$_1.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTI4MFg5NjA=/z/ZksAAOSwjDZYj578/$_1.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/OTYwWDEyODA=/z/g2YAAOSwImRYj58N/$_1.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/UXcAAOSwcGhdMkyw/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/wogAAOSw~cldMkyy/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/WEEAAOSw7zJdMky1/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/bhMAAOSwhCJdMky4/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/b-kAAOSwgs5dMky7/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/~y4AAOSwBQ1dMky9/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/wx0AAOSwtYtdMky~/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/WlEAAOSwyExdMkzC/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/cgAAAOSw5oVdMkzF/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTMwMFg4Njg=/z/nAIAAOSwf6FcwOys/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTMwMFg4Njg=/z/spsAAOSwSdNcwOyu/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTMwMFg4Njg=/z/b8IAAOSwEtBcwOyu/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/CBUAAOSwub1cwO4S/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFg3Njg=/z/oiYAAOSw0ohdMlZe/$_1.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFg3MjU=/z/X0sAAOSwrI1dMlaj/$_1.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTQyMVgxNjAw/z/~JAAAOSwjftdMleq/$_1.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTA0NlgxNjAw/z/jGMAAOSw78hdMlfd/$_1.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIxNlgxNjAw/z/4mEAAOSwpBpdMlgO/$_1.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxMTkz/z/fwAAAOSwqYxdMlhR/$_1.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/NjQzWDUxNA==/z/QT8AAOSwqaBdMmAA/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/NjM0WDY2Mw==/z/Cq0AAOSwu95dMmAN/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/NjQ4WDUxNA==/z/wkcAAOSwUmxdMmAc/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/NjU4WDUyOA==/z/j7wAAOSwyOJdMmA0/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/NjQzWDUxNA==/z/QT8AAOSwqaBdMmAA/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/NjM0WDY2Mw==/z/Cq0AAOSwu95dMmAN/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/NjQ4WDUxNA==/z/wkcAAOSwUmxdMmAc/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/NjU4WDUyOA==/z/j7wAAOSwyOJdMmA0/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/NjQzWDUxNA==/z/QT8AAOSwqaBdMmAA/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/NjM0WDY2Mw==/z/Cq0AAOSwu95dMmAN/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/NjQ4WDUxNA==/z/wkcAAOSwUmxdMmAc/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/NjU4WDUyOA==/z/j7wAAOSwyOJdMmA0/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/uWUAAOSwMsZdJMTO/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/-XYAAOSwpUVdJMT-/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/0nYAAOSwyvJdJMUN/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/X9YAAOSwPaddJMUY/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/u8EAAOSwZdhdJMUu/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/~AYAAOSwPkRdKQjm/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/B2YAAOSwoxVdKQii/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/NowAAOSw~hNdKQiB/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/~x4AAOSwupRdKQh4/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/mHUAAOSw94ddKQiH/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/KSAAAOSwsWddKQjH/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/VuIAAOSwufFdKQi6/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/aMkAAOSw~YldKQiS/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/8XsAAOSw1pddMr4W/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/x48AAOSwW7ldMr4a/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/NTM1WDU5Nw==/z/XEIAAOSw3tBdMwSz/$_57.PNG?set_id=8800005007;https://i.ebayimg.com/00/s/NDE4WDY1Mw==/z/42sAAOSwDoBdMwSx/$_57.PNG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/hicAAOSwR0pbdcSN/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/dA4AAOSw-mNbdb2Y/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/RQ0AAOSwjnpbdb2f/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/yf0AAOSwUgdbdb2m/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/RMEAAOSw-kBbdb2u/$_57.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTU4Nlg5NzU=/z/wlAAAOSwoPBdMyfH/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/PzkAAOSwYfBdMyeO/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/FNwAAOSw1V5dMyeR/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/DaIAAOSws59dMyep/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/1VcAAOSwdeNdMyfY/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTU3M1g5ODQ=/z/Lk8AAOSwPdddMygs/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/ysYAAOSwsupccwgb/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/dgAAAOSwNudccwgO/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/lIIAAOSwkhxccwgu/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/hVIAAOSwwmBccwhD/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/56sAAOSwA05ccwgy/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/z9EAAOSw32lccwhH/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/t7sAAOSwaKVccwgh/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/2UIAAOSw4~1ccwg-/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTM3MFgxMTI1/z/LpgAAOSw~G5dM0Uu/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTI1M1gxMjUz/z/X3kAAOSwDH1dM0U1/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTI1M1gxMjUz/z/OTcAAOSwSQRdM0U7/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTQ3MFgxMjUz/z/tvYAAOSwPdhdM0VJ/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/ODMzWDg5Ng==/z/DywAAOSwH2VcKmNA/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFg5MDA=/z/IY8AAOSwxJ9cKmNu/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFg5MDA=/z/FHMAAOSwEwhcKmN8/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFg5MDA=/z/ZsUAAOSwE~ZcKmOF/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFg5MDA=/z/RfcAAOSwGIZcKmOV/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFg5MDA=/z/j80AAOSw27lcKmOy/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/Kt8AAOSw8mtceEZZ/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/wjcAAOSwkhtceEZs/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/UZwAAOSwmWNceEZ7/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/uAQAAOSw0dFceEaV/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/a4oAAOSwrn9ceEbA/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/iwoAAOSw-JtceEbu/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/-kcAAOSw2hhceEb4/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/CR0AAOSwlLdceEcT/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/t-QAAOSwmPFceEco/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/WHMAAOSwivlceEcz/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/Y3UAAOSwmwFceEdB/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/3EUAAOSwcaZceEec/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/AEYAAOSwQEpdM23F/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/megAAOSwuXtdM23P/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/LSwAAOSwIbFdM23M/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/1jgAAOSwLW9dM23i/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/eWgAAOSwRaJdM23b/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/tTAAAOSwArNdM23W/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/lz8AAOSwVEJdM23S/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/qiQAAOSwtOVdM23f/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/uQ0AAOSwoIFdM23l/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/8PEAAOSwcnpdM23I/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/R2YAAOSwFmtdM23o/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/OTg2WDEyMDA=/z/P0AAAOSwFlNcdfKl/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/ODAwWDEyMDA=/z/8ogAAOSw0bpcdfKp/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/ODAwWDEyMDA=/z/Yd4AAOSwyutcdfKv/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/ODAwWDEyMDA=/z/Q5wAAOSwGNFcdfK0/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/ODAwWDEyMDA=/z/CXEAAOSw14hcdfK6/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/ODAwWDEyMDA=/z/WjIAAOSwLXBcdfLA/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/NTUwWDQyMw==/z/~9cAAOSwwbxc8Yws/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTU4NlgxNDkw/z/bbYAAOSwQKlc8Yw8/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/bioAAOSw9J5c8Yto/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTA2M1gxMDE5/z/QzMAAOSw3dZc8Yx4/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/fqsAAOSwUFtc8Yt6/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/uIUAAOSwGMBc8Yt0/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTU4NlgxNDEw/z/tDcAAOSwhf9c8Y1f/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/E1UAAOSwAhNc8Yt-/$_57.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/qDgAAOSwoRFdESEP/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTA1OVgxMDM3/z/~uIAAOSwsMZdESNn/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/L44AAOSwy1ZdESEo/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/vrsAAOSwjG1dESEl/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTA2M1gxMDk4/z/cOcAAOSwVcFdESN3/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTQzN1gxMDA2/z/EeQAAOSwD1ldESOD/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTQxOVgxMDE5/z/R~MAAOSwiFNdESOI/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/nQ4AAOSwdeVdESD1/$_57.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFg5MDA=/z/zpwAAOSwi3tbDN0r/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/OTAwWDEyMjE=/z/vvcAAOSwj-BbDN1V/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/ODkzWDE0NDA=/z/79cAAOSwkkNbDN05/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/OTU3WDkwMA==/z/kfAAAOSwNSJbDN1A/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/OTc2WDkwMA==/z/Vk4AAOSw7tRbDN1q/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/OTAwWDE0NDA=/z/qCAAAOSw~U5bDN1h/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTE0OVg5MDA=/z/LXMAAOSwkKBbDN1y/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTE1MFg5MDA=/z/B5sAAOSwjh5bDN16/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTQ0MFg5MDA=/z/dlcAAOSwlKRbDN2E/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTQ0MFg5MDA=/z/ytgAAOSwD7dbDN2Q/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTEzNlg2NDA=/z/5K4AAOSwYX9dM-MV/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/R3oAAOSw9HNdMqLe/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/-loAAOSwHk9dMqMV/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/8LwAAOSwSCRdMqMr/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/WNsAAOSwK39dMqLp/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/Pi8AAOSwTj9dMqLP/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/BogAAOSwqG5dMqM3/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/zfsAAOSwpkddMqL3/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/a9cAAOSwTMtdMqML/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/vhwAAOSwsNNdMqMh/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/dL0AAOSwkq9dMqMB/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTI5OVg2MzE=/z/V2IAAOSwQtxdMoe7/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/OTgxWDcyOQ==/z/dq0AAOSwXV9dMofS/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTMxNFg3MTU=/z/afgAAOSwdAFdMofB/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTQzNVg1Mzg=/z/kEwAAOSwse1dMoeq/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTUzOVg1Nzc=/z/BhsAAOSwEhBdMoek/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/NjIzWDExMzg=/z/kYYAAOSwlPhdMoel/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTI3Nlg3NzA=/z/7ooAAOSw7kxdMoeU/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTM3NFg3NzA=/z/APYAAOSwkvxdMoed/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/OTc5WDc3MA==/z/s3IAAOSw6w5dMoez/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTM3OVg3NzA=/z/0ugAAOSwTC1dMofX/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/NTg4WDExODA=/z/ookAAOSwK6ZdMofG/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTA1N1g3NzA=/z/gdsAAOSwWkxdMofL/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTQwN1g5NTE=/z/qPQAAOSwqo5dNFwp/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTQ4Mlg5OTA=/z/I44AAOSwUGddNFwf/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/5HEAAOSwFSFdNF0r/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/ZoIAAOSwC8FdNF0W/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTE4MlgxNDY3/z/9TcAAOSwtOVdNFwK/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTEyOFgxNDY3/z/93QAAOSw14RdNFwV/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/NWkAAOSwcytdNFvd/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/BLYAAOSwIUddNFvU/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/cOkAAOSwDoBdNF1F/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/QEEAAOSw-1JdNFwA/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/O9EAAOSwljJdNFu9/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/D70AAOSwYX9dNFuv/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTYwMFg5MDA=/z/MHwAAOSwMudbjXgY/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTI5Nlg3NzE=/z/YbAAAOSwcMhbjXgj/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTUyNVg4MDM=/z/dZQAAOSwx0FbjXgs/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFg5MDA=/z/F4kAAOSwqMpbjXg6/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTYwMFg5MDA=/z/1-0AAOSwbrldKtE2/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTQwNFg3OTk=/z/yBkAAOSwQsZdKtFh/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFg5MDA=/z/1tkAAOSwDipdKtE~/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/OTAwWDE2MDA=/z/~MIAAOSww6NdKtEd/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/NjAzWDYzNA==/z/SyUAAOSwi7BdIrHI/$_57.PNG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTU4NlgxMDYw/z/hksAAOSwY7lcbXR8/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTE4MVg2MzQ=/z/OUIAAOSw6DNcbXSG/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNTk5/z/VPMAAOSwyutcbXQi/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNTk5/z/CTQAAOSwCyVcbXQ0/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTU4NlgxMDI4/z/3LQAAOSwVDpcbXS-/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTE4NVg2NTQ=/z/SqEAAOSw6aVcbXSq/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNTk5/z/MewAAOSwcyVcbXQr/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTU5MlgxNjAw/z/fxYAAOSwi0xaG5eV/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/gKwAAOSw3fZaG5eY/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNDU0/z/QgUAAOSwv-ZaG5eV/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/xOAAAOSwC-taG5eV/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/NzQ5WDk5OQ==/z/dt4AAOSwmuVaZkM-/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/OTk5WDc0OQ==/z/wu8AAOSwUd9aZkMr/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/OTk5WDc0OQ==/z/qPoAAOSwX7BaZkMn/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/OTk5WDc0OQ==/z/OEoAAOSwsZJaZkMp/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/OTk5WDc0OQ==/z/mPAAAOSwJc9aZkMt/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/OTk5WDc0OQ==/z/J98AAOSwhiZaZkMq/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/t20AAOSw4wRdNJbS/$_32.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/1b4AAOSwfUZdNJbI/$_32.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/fEUAAOSwAAJdNJbA/$_32.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/I5QAAOSwn3RdNJbj/$_32.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/BtAAAOSwvPtdNJbg/$_32.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/AqUAAOSw3tBdNJbg/$_32.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/BekAAOSwwNJbV/$_32.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxMDM0/z/NnAAAOSwFoNcSTAM/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/RxgAAOSw9ptcSTCv/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/57IAAOSwfBlcSTAD/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/JscAAOSwakxcSS~9/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/seIAAOSw5bxcSTAB/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxMDc5/z/p80AAOSwGWJcSTAI/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/SmUAAOSwJ~xcSTAG/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/9jQAAOSwyVRdG8TT/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/L2QAAOSwQ8xdGuFX/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/NzIAAOSw2EZdGuFZ/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/To8AAOSwxDBdGuFc/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/iJoAAOSwmrVdGuFh/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/720AAOSwDJFdGuFj/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/CoQAAOSw8BNdGuFl/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/lOEAAOSwctddGuFn/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/I28AAOSwaj9dGuFp/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/H7sAAOSwsB5dGuFr/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/EjkAAOSwpoVdG8TM/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/xToAAOSwQsZdNKm9/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/1YUAAOSwgmVdNKmx/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/tC4AAOSwPQBdNKm1/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/LoYAAOSwJHZdNKm7/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/OGsAAOSwDV5dNKm4/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/tOkAAOSwlQhdNKm0/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/D-cAAOSw27RdNKm6/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/Z3gAAOSw5CddNKrQ/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/04oAAOSwIzpdNKrc/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/UsoAAOSwO5JdNKrZ/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/XFUAAOSwoR1dNKre/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/tPYAAOSwS-FdNKrS/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/8ccAAOSwr-ZdNKrU/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/yhMAAOSw~BtdNKrb/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxMDcx/z/KCsAAOSwXXVapIiI/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTA3MVgxNjAw/z/hi8AAOSwfghapIiG/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxMDcx/z/0W4AAOSwheZapIiO/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTA3MVgxNjAw/z/KsgAAOSw8hhapIiP/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTA3MVgxNjAw/z/UVMAAOSw~JRapIiK/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTA3MVgxNjAw/z/hgkAAOSwMxdapIiM/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/~xsAAOSwccFdNPMl/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/lhkAAOSw2QtdNPMl/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/fJkAAOSww~BdNPMm/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/YiQAAOSw~BxdNPRM/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/uGwAAOSwTs5dNPRM/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/UCsAAOSwJ9RdNPRL/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNDQ2/z/fFYAAOSw-q9dNPRL/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNDY4/z/97cAAOSw1J1dNPRL/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/jmIAAOSwkfFdNPRN/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/mwAAAOSws8RdNPRN/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/EQkAAOSw3QldNPRN/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/3M8AAOSwc5VdNPfA/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/8mEAAOSw~wtdNPfQ/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/-acAAOSwXyNdNPfO/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/fgoAAOSwGbldNPfJ/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/RokAAOSw~BldNPfC/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/qeYAAOSwnBpdNPfL/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/AtYAAOSwhQJdNPfM/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/UYoAAOSwhktdNPfG/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTQ4MVg5Mjc=/z/op4AAOSwZWNdK8bH/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/wtMAAOSway5dK5oK/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/6W8AAOSwAMJdK5oM/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/4FAAAOSw~YldK5oN/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTMyN1g4NDg=/z/f6kAAOSw4aRdK8be/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/8lIAAOSwOwZdK5oU/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/dacAAOSwmgVdK5oY/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/OTM2WDE1ODc=/z/wX8AAOSwZbNdK8cC/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/I60AAOSwgn1dK5uD/$_57.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/rTYAAOSw0ZZbu8Pq/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/bBUAAOSwO2hbu8Pt/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/h3AAAOSwvYZbu8Pw/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/zW0AAOSwSYdbu8Pz/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/Lg8AAOSwz6pbu8P2/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/1cgAAOSwBgpbu8P5/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/e2kAAOSwl0pdNSHh/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/G7IAAOSwDH1dNSGU/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/lUkAAOSwly9dNSGT/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/tgEAAOSw1g1dNSGQ/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/NDgwWDY0MA==/z/IeYAAOSwgApXCj7T/$_1.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/NDgwWDY0MA==/z/PBsAAOSwq19XCj73/$_1.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/NDgwWDY0MA==/z/DHYAAOSwSzdXCj8O/$_1.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/bIoAAOSwPdddGODE/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/CIoAAOSwBRBdGODG/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/4DoAAOSw41ddGODI/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/uzgAAOSwyvtdGODK/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/yuYAAOSwgmVdGODR/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/5eYAAOSwT~hdGODT/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTE5N1g3MzA=/z/9C4AAOSwiG1dFthI/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTMzOFg3MzE=/z/QWsAAOSwqx1dFth5/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/OTc1WDczMA==/z/n0wAAOSwp3FdFtiM/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTM5M1g2ODc=/z/aJsAAOSwhxJdFtia/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTI5MFg3MTE=/z/sdoAAOSw-0FdFtil/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTAxMlg3MDc=/z/EZEAAOSwvfFdFtiw/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/OTA4WDc5Ng==/z/BdAAAOSwlyxdNdYH/$_57.PNG?set_id=8800005007;https://i.ebayimg.com/00/s/OTA4WDc5Ng==/z/K7IAAOSwKIhdNdYJ/$_57.PNG?set_id=8800005007;https://i.ebayimg.com/00/s/OTA4WDc5Ng==/z/IaUAAOSwe9ddNdYM/$_57.PNG?set_id=8800005007;https://i.ebayimg.com/00/s/OTA4WDc5Ng==/z/fn0AAOSwDdldNdYO/$_57.PNG?set_id=8800005007;https://i.ebayimg.com/00/s/OTA4WDc5Ng==/z/MPEAAOSwRvhdNdYk/$_57.PNG?set_id=8800005007;https://i.ebayimg.com/00/s/ODU2WDkxNg==/z/J3EAAOSwNaBdNdYn/$_57.PNG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/FF0AAOSwFmRbgr38/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/pIYAAOSwKqlbgr3~/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/svYAAOSwHj1bgr4C/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/Fg8AAOSwik9bgr4F/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/6FgAAOSwiIRbgr4I/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/VWIAAOSw1Btbgr4K/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/jlUAAOSwtLtbsDQq/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/c9IAAOSwXUdbsDQr/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/KcMAAOSwBRVbsDQv/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/EBQAAOSw1cdbsDQw/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/f2IAAOSwOXJbsDQy/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/syIAAOSwMFFbsDQz/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/Zc0AAOSw8MJbsDQ0/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/4uIAAOSwOIBdNd5K/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/~dYAAOSwPBJdNd5P/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/UvIAAOSw62RdNd5V/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/HtQAAOSwSnRdNd5Y/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTYwMFg5MDA=/z/KhIAAOSwIbFdNfFs/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/OTAwWDE2MDA=/z/2yQAAOSw2opdNfF0/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/OTAwWDE2MDA=/z/-hEAAOSwOdldNfGC/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFg5MDA=/z/XxYAAOSwm~hdNfGQ/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFg5MDA=/z/JqMAAOSwKzVdNfGi/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFg5MDA=/z/9igAAOSwnHBdNfGw/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFg5MDA=/z/5gAAAOSwPHZdNfG9/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFg5MDA=/z/qRAAAOSwkl9dNfHR/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFg5MDA=/z/ERIAAOSwLjhdNfHl/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/NzQ5WDc0NA==/z/tt8AAOSw3kBdKfaX/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/ODc4WDY3Ng==/z/dOAAAOSwidFavCVs/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/NzQ5WDc0OQ==/z/VrQAAOSwsS9dKfax/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/NzQ4WDcxOA==/z/TMoAAOSwz21dKfbF/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/NzQyWDc0OQ==/z/j1wAAOSwS-FdKfbp/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/NzQ4WDc0OQ==/z/icoAAOSwg6ldKfb9/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/BhYAAOSw4apdNgA~/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/cYIAAOSwYMldNgAq/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/gY0AAOSw3YBdNgAw/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/w8wAAOSw09ZdNgAz/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/oD4AAOSwuXtdNgA5/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTA5MVgxMDgw/z/kToAAOSwMnZcwFHg/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTQzOVgxMDgw/z/9r4AAOSwAb1cwFHi/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTE0MVgxMDgw/z/tNsAAOSwyJFcwFHk/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTEzM1gxMDgw/z/UK8AAOSwb7RcwFHn/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTMxM1gxMDgw/z/h~EAAOSwTwtcwFHq/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/NTMzWDYwMA==/z/YVEAAOSwhBVdNgga/$_57.PNG?set_id=8800005007;https://i.ebayimg.com/00/s/NTMzWDYwMA==/z/~h8AAOSwrSpdNggc/$_57.PNG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/rYkAAOSw0TpcjCFB/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/NTc2WDgyNg==/z/mS4AAOSwdNZc8XHI/$_57.PNG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/~TAAAOSwGMFcjCEn/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/GhQAAOSwylhci-cV/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/fzwAAOSwoddcjCEy/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/lbcAAOSw45VdNhvW/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/rvEAAOSwOPldNhva/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/J2UAAOSwul9dNhvT/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/ngEAAOSw0G9dNhvN/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/qfEAAOSw2BFdNhvS/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/ZW4AAOSwLbJdNhvK/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/~rAAAOSw~p5dNhvY/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/H1EAAOSwLM9dNhvP/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/GpUAAOSwEwFdNh6r/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/T9EAAOSwe9ddNh6t/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/WlYAAOSwKTddNh6v/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/w1QAAOSwt~FdNh6x/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/KrIAAOSwOA1Z~MHx/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/Yj8AAOSwe51Z~MHn/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/JEcAAOSwc2FZ~MHa/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/NTgwWDU4MA==/z/-K0AAOSwsU5dNm4c/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/NTgwWDU4MA==/z/BlwAAOSw6OtdNm4f/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/NTgwWDU4MA==/z/9FIAAOSwexddNm4g/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/NTgwWDU4MA==/z/ofUAAOSwqo5dNm4i/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/TgMAAOSwNCRdNouU/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/-K8AAOSwgHRdNouY/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/ZbMAAOSwufFdNouJ/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/FKQAAOSw3-xdNouH/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/lpkAAOSwPH9dNouF/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/MKMAAOSwuyNdNouR/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/QI0AAOSw~w9dNouP/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/wawAAOSw3YBdNouW/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/aJgAAOSwfURdNpOX/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/EyYAAOSw8bFdNpOc/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/NRcAAOSwtKRdNpOf/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/s5oAAOSwyNtdNpOk/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/kcAAAOSw4R1dNpOo/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/YT4AAOSwjG1dNpOa/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/vl8AAOSwjsldNpO3/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/N3kAAOSwuU9dNpO~/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/DrAAAOSwLfNdNpOj/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTI5N1g5MzY=/z/DRIAAOSwwf5dNpPN/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/V8AAAOSwPqFdNpPU/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/ftYAAOSwxWxdNroZ/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/MPIAAOSwQHBdNroQ/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/u04AAOSwFoZdNroz/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/Tp8AAOSwfSldNroj/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/dt8AAOSwVeZdNroq/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/NTMzWDYwMA==/z/oJoAAOSwaQJdNuTQ/$_57.PNG?set_id=8800005007;https://i.ebayimg.com/00/s/NTMzWDYwMA==/z/yaEAAOSwTC1dNuTM/$_57.PNG?set_id=8800005007;https://i.ebayimg.com/00/s/NTMzWDYwMA==/z/4N8AAOSwQCBdNuTI/$_57.PNG?set_id=8800005007
# https://i.ebayimg.com/00/s/NTMzWDYwMA==/z/db0AAOSwVG9dNuYC/$_57.PNG?set_id=8800005007
# https://i.ebayimg.com/00/s/NDgwWDY0MA==/z/qY4AAOSw-itXrw7S/$_1.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/NDgwWDY0MA==/z/~pIAAOSw6n5Xrw7g/$_1.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/NDgwWDY0MA==/z/7xAAAOSw0UdXrw7w/$_1.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/NDgwWDY0MA==/z/O5kAAOSwaB5Xrw79/$_1.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/NDgwWDY0MA==/z/t~IAAOSwHoFXrw8P/$_1.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/NDgwWDY0MA==/z/qmQAAOSwgZ1Xrw8a/$_1.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/NDgwWDY0MA==/z/u90AAOSwHoFXrw8q/$_1.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTIwMFgxNTk5/z/mbgAAOSwPUZbW69s/$_1.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTE2OVgxMDY4/z/BQ8AAOSwrh5bW3bh/$_1.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTE1N1gxMDUy/z/k90AAOSwr85bW3Xl/$_1.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNTk5/z/LIcAAOSwSI5bW6~2/$_1.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNTk5/z/3QoAAOSwWOdbW7A7/$_1.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/fr0AAOSwcCJcmVhq/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/xLQAAOSw0bpcmVh2/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/R6wAAOSwvlRcmVh~/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/D~gAAOSwEVZcmViI/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/JhIAAOSwFzNcmViZ/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/hC0AAOSwPilcmVii/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/OTAwWDE2MDA=/z/I1MAAOSwtGtcWLJT/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/OTAwWDE2MDA=/z/658AAOSwnGVcWLKG/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTQzM1g4Mzg=/z/sMUAAOSw6~pcWLKp/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFg5MDA=/z/xQAAAOSw-k5cWLK6/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/ODk5WDY5Ng==/z/ZyYAAOSwTqtcWLLh/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTIwMlg2NjY=/z/R7wAAOSwnm1dN1F~/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/OTk5WDY2Ng==/z/jBgAAOSwYX9dN1GM/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/OTk5WDY2Ng==/z/GaYAAOSwm3ldN1Gl/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/OTk5WDY2Ng==/z/Kn0AAOSw0eNdN1Gz/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/OTk5WDY2Ng==/z/sBoAAOSwljJdN1G~/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/NjY2WDk5OQ==/z/Z7sAAOSwdtBdN1HO/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/DNkAAOSwZqRc03kO/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/2PEAAOSwF2hc03kM/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/6KIAAOSwkbVc03kT/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/xvIAAOSwN3lc03kQ/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/AbAAAOSwopVc03kS/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/7TAAAOSwvDZc03kK/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/ZugAAOSwKltc03kV/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/MNYAAOSwXwtdBx-N/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/3XQAAOSwFaldBx-P/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/obIAAOSw~CVdBx-Q/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/PUkAAOSw6HtdBx-S/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/HqsAAOSwqLFdBx-X/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/jvUAAOSwitFdBx-V/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/LT0AAOSwCcJdBx-Z/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/nMwAAOSwAUVdN1L5/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/5jwAAOSwEDBdN1L8/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/u1QAAOSwh~1dN1MM/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/OnwAAOSwzpddN1MC/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/skoAAOSw2fRdN1MB/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/ACgAAOSwgWtdN1L-/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/PBwAAOSw7wZdN1MI/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/yvoAAOSwG-NdN1ME/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/PCEAAOSw3QldN1MK/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/3qIAAOSw2bhdN1MG/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/aw4AAOSwcENdN1MN/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/50QAAOSwYTpdN1tY/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTEyNVgxMDcz/z/F5gAAOSwEC5dN1vx/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/4DwAAOSwOHNdN1tf/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTE4OVgxMTYx/z/YYIAAOSwl-ddN1wG/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/y8IAAOSwdgtdN1tV/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/mykAAOSwKg9dN1yP/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/DRIAAOSwSCRdN1xZ/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/2s4AAOSw5nZdN1xc/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/e70AAOSwkGldN1xe/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/tBIAAOSwgW5dN1xh/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/vyQAAOSw78hdN1xj/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/xm4AAOSwhFpdN1xl/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/6wYAAOSwytpdN1xn/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/SHwAAOSwLzxdN1xq/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTIwMFgxMjAw/z/YwwAAOSwx95dN2zm/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTM2OFgxMjUy/z/uG8AAOSw0xtb~Olp/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTI0OFgxNDUx/z/rBAAAOSwNepb~Omy/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTMzM1gxMzM3/z/ZxwAAOSwsO5b~Ol3/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTM2MlgxMjI3/z/FlEAAOSwaalb~OmD/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTAzMFgxMDg2/z/eSIAAOSwVixb~Om4/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNTE0/z/r~AAAOSwN3Nb~Ok~/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNTc4/z/5mIAAOSwBqZb~Olw/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNTM2/z/vLgAAOSwBMpb~Om-/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTM0NVgxMjky/z/bcwAAOSw5iRb~OnH/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTMxM1gxMjM3/z/n5oAAOSwcOZb~OnN/$_12.JPG?set_id=880000500F
# ...
# https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/9SMAAOSw~slcSOrz/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/5rkAAOSwHSdcSOr2/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/T5AAAOSwcttcSOr5/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/4BgAAOSwltxcSOr8/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/JKwAAOSw3CdcYdky/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTQ1NlgxNjAw/z/RysAAOSw04ZcYdkw/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/e1MAAOSwC4lcYdks/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTQ2NlgxNTA2/z/ijoAAOSwa1hcSLmV/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTUxNlgxNjAw/z/CkIAAOSwuAVcYdk2/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/pKoAAOSwoURcSPhN/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/04kAAOSwviBcSPhR/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/Qb0AAOSwb15cSPhV/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/PiUAAOSwZrZcSPhZ/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/DNwAAOSwWmNaoM6y/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/mE4AAOSwKX9aoM6r/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/y7AAAOSwhjRaoMxG/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/IicAAOSwKJFaoMxK/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/tckAAOSwE0ZaoMxO/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/Cc4AAOSwxwRaoMxQ/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/CuUAAOSwDdNaoMxe/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/IiMAAOSwwChaoMxj/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/mQIAAOSw3FpaoMxo/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/zNIAAOSw~jJaoMxr/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/-CkAAOSwiJZcSS7B/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/DekAAOSwuwlcSS69/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/xfEAAOSwMKVcSS7H/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/9MYAAOSwFlJcSS66/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/EkwAAOSwrZBcSefC/$_32.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/-9AAAOSwt0dcSefC/$_32.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/wMUAAOSwZ-9cSefj/$_32.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/5l8AAOSwjW9cSefv/$_32.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/ARcAAOSwlt9cSjcy/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/5LEAAOSwZV1cSjcn/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/PJAAAOSwijhcSjcr/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/oN8AAOSwuA9cSjcv/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/KM0AAOSwqjhcSj51/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/KA0AAOSwhY9cSj5t/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/c38AAOSwVXdcSj5w/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/mAoAAOSwEqVcSj5z/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/CewAAOSwdgxcSkL9/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/9JMAAOSwqoxcSkL1/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/X3oAAOSwsQJcSkL3/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/rTAAAOSwEXtcSkL7/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/2aUAAOSwsGpcSm8T/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/ae4AAOSw7fhbeSAP/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTQ0MFgxNDQw/z/ooMAAOSwMPxbeSA4/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTQ0MFgxNDQw/z/fQQAAOSwoyVbeSBM/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/RwIAAOSwi6NbfgXn/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTQ0MFgxNDQw/z/JJ8AAOSwyUtbeSCw/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTQ0MFgxNDQw/z/vacAAOSwZ-lbeSDE/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/oF0AAOSwPrlbfhZK/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/fLEAAOSwkelcSrEC/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/gwMAAOSwaEdcSrEx/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/MHoAAOSwH0lcSrGB/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/mW0AAOSw1rpcSrG1/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/PKAAAOSwQXlcSrIJ/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/YEAAAOSwtYZcSrJN/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/D3YAAOSwHp5bYH4l/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/2mIAAOSwQ2JbYH4o/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/jwQAAOSwx~pbYH4q/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/a2UAAOSwjMdbYH4s/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/BDwAAOSwuOpbYH4u/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/tGQAAOSwjYdbYH4w/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/DRcAAOSwQFhbYH4z/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/3ycAAOSwrqBbncqT/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/nWgAAOSwq2Jbncqd/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/6HMAAOSwWEBbncqw/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/-BcAAOSw6kNbncqj/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/YO8AAOSwx-1bncqn/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/hhUAAOSwjYVcTQG6/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/WuMAAOSwLDlcTQG-/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/GbAAAOSwIndcTQHM/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/5P0AAOSwbWJcTQHS/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/Zr4AAOSwgdtcTQHZ/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTI4MFg3MjA=/z/~4UAAOSwoURcTd2Q/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTI4MFg3MjA=/z/nvYAAOSwOHpcTd2R/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTI4MFg3MjA=/z/NpAAAOSwgdtcTd2S/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/wn0AAOSw5tNcTgmo/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/vfQAAOSwsQJcTgmr/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/HT4AAOSwYwZcTgmu/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/32wAAOSwkDtcTgmx/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/NrMAAOSwgGhcThSX/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/ksIAAOSwIbtcThRY/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/LnMAAOSwew9cThR-/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/OTE3WDE1NjY=/z/TLQAAOSwydZcThSO/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/cBUAAOSwdGZcThRf/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/FHcAAOSwWz5cR7cl/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/is0AAOSwLKhcR7Sd/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/TysAAOSwNqxcR7Sk/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/CScAAOSwF5VcR7cy/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/SO4AAOSwviBcR7Sw/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/~TEAAOSw6EpcR7S1/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/wB8AAOSw11BcR7dB/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/6yIAAOSwvGZcR7dN/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/Is0AAOSwdhdcR7dX/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/wC0AAOSw11BcR7di/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/-FUAAOSwdaVcR7TO/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/n4AAAOSwqoxcR7TT/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/IjkAAOSwcZ1cTkqD/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/irYAAOSwpptcTkqR/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/Ml4AAOSwgyZcTkqc/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/6icAAOSwRKVcTkqX/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/r8kAAOSwGyZcTkqi/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTQyMVg4MjM=/z/bfEAAOSwWTRWvRao/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTExN1g5OTk=/z/xeIAAOSwuAVWvRbB/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTE5NVgxNjAw/z/pR8AAOSwKtVWvRbO/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTUzNVg3OTI=/z/yEYAAOSwuAVWvRbb/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTE5NVgxNjAw/z/hgAAAOSwe7BWvRbi/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/-ZEAAOSwm6VbpXXY/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/wXQAAOSw85JbpU5k/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/WRkAAOSwbehbpU40/$_57.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/McsAAOSw-MRbpXYE/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/tfIAAOSwPR9bpXYU/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/VR0AAOSw53hbpXYf/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/RRcAAOSwpTJbpXYi/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/yuIAAOSwvu1bpXYu/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/gFkAAOSwe~BbpXY9/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/Dq8AAOSwIDJbpXZF/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/rIAAAOSwu3ZcT-NV/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/5rIAAOSwkDtcT-NL/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/Uw8AAOSw66JcT-NO/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/5WEAAOSwlINcT-NR/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/-uYAAOSwfqJcT-Nc/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/1oEAAOSwCitcUdMx/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/Xl4AAOSwEwhcUdM~/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/zUwAAOSwGBRcUdNF/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/U2cAAOSwdgxcUdMs/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTIwMFgxNTk5/z/mDUAAOSw~FJZLNuo/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNTk5/z/mKIAAOSw~FJZLNu5/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNTk5/z/uUMAAOSwDiBZLNvI/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/A4UAAOSwnQ1cS7WU/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/rYUAAOSwgrZcS7WW/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/-KIAAOSwTxJcS7WX/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/2KEAAOSw6~pcS7WZ/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/vloAAOSwMKVcS7Wa/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/fqAAAOSwrfRcS7Wd/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/It8AAOSw1vxcS7Wq/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/Ho4AAOSw2TVcS7Ws/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/KK8AAOSwK89cVOb9/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/wbIAAOSwh99cVOcB/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/fCAAAOSwWz5cVOcG/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/40AAAOSw0YVcVOcK/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/x70AAOSws7VcVOcO/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/~DAAAOSwj9JcVOcS/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/XhwAAOSwmMNcVOcX/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/9v8AAOSwm~1cVOca/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/BUoAAOSwQqNcVOci/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/aNgAAOSwe~lcVOcn/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/oVEAAOSwj9hcVOcs/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/3TsAAOSwHptcVOcy/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/Qe0AAOSw5r1cVXfn/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/JCEAAOSw1T1cVXfr/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/R~oAAOSw7F9cVXfv/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/ODAwWDU1Mw==/z/NhoAAOSwwkRcWFrS/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/ODc5WDU4Ng==/z/Bt0AAOSwwDJcWFnZ/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTUwMFgxMDAw/z/c3sAAOSwxLFcWFnl/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTUwMFgxMDAw/z/DSUAAOSwkHxcWFow/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/ODc5WDU4Ng==/z/F~UAAOSwP85cWFpJ/$_57.JPG?set_id=8800005007;https://i.ebayimg.com/00/s/MTIwMFgxMjAw/z/ypIAAOSw0i9cWFrH/$_57.JPG?set_id=8800005007
# https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/EgoAAOSwVAtcWLw6/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/HkMAAOSwvpVcWLw4/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/mpgAAOSwIbpcWLw2/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/DjQAAOSw5bxcWLxA/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/0KAAAOSwjmFcWLw8/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/pREAAOSwmYxcWLwz/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxNTk4/z/D~EAAOSwdiFcWu2K/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/204AAOSw4ntcWu2j/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/L1wAAOSwEKxcWu2z/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/ZhgAAOSwg0dcWu3A/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxNjAw/z/aPYAAOSwAdFcWu2U/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/hJoAAOSwjW9cW0Mr/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/krQAAOSw0ylcW0Mf/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/390AAOSwRbpcW0Md/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/mm8AAOSw6~pcW0Mh/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/7hQAAOSwsQJcW0Mb/$_12.JPG?set_id=880000500F;https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/rKMAAOSwYyVcW0Mj/$_12.JPG?set_id=880000500F
# https://i.ebayimg.com/00/s/NTAwWDM4NQ==/z/4JoAAOSwVblcXTrQ/$_1.PNG?set_id=8800005007;https://i.ebayimg.com/00/s/NTAwWDM4NQ==/z/Df4AAOSwndBcXTrQ/$_1.PNG?set_id=8800005007;https://i.ebayimg.com/00/s/NTAwWDM4NQ==/z/aToAAOSwqolcXTrQ/$_1.PNG?set_id=8800005007
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ```python
# df = pd.DataFrame(columns=['Name', 'Age'])
#
# df.loc[1, 'Name'] = 'Rocky'
# df.loc[1, 'Age'] = 23
# ```
# ---
#
# ```python
# features_df = pd.DataFrame(columns=['Features'])
#
# # key & features_pred variable come from the function
# df.loc[key, 'Features'] = features_pred
#
# # some pandas merging df function here --> features_df merged onto mod_dataset
# ```

# %%
# from sklearn import cluster

# # X =
# agglo = cluster.FeatureAgglomeration(n_clusters=5, affinity='manhattan')

# %%
#Turning Other Images into list of arrays
#The same thing we do for primary images but it's gonna be for all the images

# %%
#Full Custom Transformer, should include all preprocess steps as functions class functions

# %%
#Code skeleton for evaluation 

#Some function that takes in the predicted labels and ground truth labels
# def whatever (predictions, groundTruth)
    
    #Get the precision score with sklearn.metrics.precision_score

    #Get the recall score with sklearn.metrics.recall_score

    #Get the f1 score with sklearm.metrics.f1_score

    #Return the f1 score
